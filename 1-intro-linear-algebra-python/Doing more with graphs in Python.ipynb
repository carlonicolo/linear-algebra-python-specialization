# %%
#pip install matplotlib
import pandas as pd #converts dataset to pandas dataframe
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %% [markdown]
# ### Basic Example

# %%
x = np.linspace(-3,3,20)

y = x**2
x
# Out:
# array([-3.        , -2.68421053, -2.36842105, -2.05263158, -1.73684211,
#        -1.42105263, -1.10526316, -0.78947368, -0.47368421, -0.15789474,
#         0.15789474,  0.47368421,  0.78947368,  1.10526316,  1.42105263,
#         1.73684211,  2.05263158,  2.36842105,  2.68421053,  3.        ])

# %%
plt.plot(x,y,'b-')

# %% [markdown]
# ### Basic Matplotlib Commands

# %%
plt.plot(x,y, 'g*-')
plt.xlabel('X label')
plt.ylabel('Y label')
plt.title('Our first Plot')
# Out:
# Text(0.5, 1.0, 'Our first Plot')

# %% [markdown]
# ### Creating Multiplots on Same Canvas

# %%
plt.subplot(1,2,1)
plt.plot(x,y, 'g')
plt.title('Y is function of X')

plt.subplot(1,2,2)
plt.plot(y,x, 'r--')
plt.title('X is a function of Y')
# Out:
# Text(0.5, 1.0, 'X is a function of Y')

# %% [markdown]
# ### Introduction to the Object Oriented Method

# %%
fig = plt.figure(figsize=(10,8))
axe1 = fig.add_axes([0.1,0.1,0.8,0.8])
axe1.plot(x,y,'b-o',lw=2)
axe1.set_title('Larger Graph')

axe2 = fig.add_axes([0.3,0.1,0.2,0.3])
axe2.plot(y,x,'r->',lw=2)
axe2.set_title('Saller Graph')
# Out:
# Text(0.5, 1.0, 'Saller Graph')

# %% [markdown]
# ### Subplots()
# The subplots() object will act as a more automatic axis manager

# %%
# Use similar to plt.figure() except use tuple unpacking to grab fig and axes
fig, axes = plt.subplots()

# Now use the axes object to add stuff to plot
axes.plot(x,y, 'r')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title')
# Out:
# Text(0.5, 1.0, 'title')

# %% [markdown]
# Then you can specify the number of rows and columns when creating the subplots() object:

# %%
# Empty canvas of 1 by 2 subplots
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(12,5))

# %%
# Axes is an array of axes to plot on
axes
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %% [markdown]
# We can iterate throught this array

# %%
for ax in axes:
    ax.plot(x,y, 'k')
    ax.set_xlabel('x-label')
    ax.set_ylabel('y-label')
    ax.set_title('Repeating')
    
# display the figure object
fig

# %% [markdown]
# ### Save figures
# Matplotlib can generate high-quality output in a number formats, including PNG, JPG,ESP,SVG,PGF,PDF.
# To save the figure to a file we can use the **savefig** method in the **Figure** class:

# %%
fig.savefig("filename.png")

# %%
fig.savefig("filename.png", dpi=200)

# %% [markdown]
# ### Legends, labels and titles
# Now that we have covered the basics of how to create a figure and add axes instances to the canvas, let's look at how decorate a figure with titles, axis labels, and legends.
#
# #### Figure titles
# A little can be added to each axis instance in a figure. To set the title, use the **set_title** method in the axes instance:

# %%
ax.set_title("title");

# %%
# Axis labels
ax.set_xlabel("x")
ax.set_ylabel("y")
# Out:
# Text(1576.607843137255, 0.5, 'y')

# %% [markdown]
# ### Legends
# You can use the label="label text" keyword argument when plots or other objects are added to the figure, and then using the **legend** method without arguments to add the legend to the figure:

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x, x**2, 'r*', label="x**2")
ax.plot(x, x**3, 'g--', label="x**3")
ax.legend(loc=0)

# %%
# Legend options...
ax.legend(loc=1) # upper right corner
ax.legend(loc=2) # upper left corner
ax.legend(loc=3) # lower left corner
ax.legend(loc=4) # lower right corner

# ... may more options are available

# Most common choice
ax.legend(loc=4) # let matplotlib decide the optimal location
fig

# %% [markdown]
# ## Use four different graphs to plot data
#
# * Styles
# * Histogram
# * Boxplot
# * Line Width
#
# ### Style

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
#plt.style.use('fivethirtypeeight')
#plt.style.use('Solarize_Light2')
#plt.style.use('bmh')
#plt.style.use('classic')
#plt.style.use('seaborn-deep')
#plt.style.use('seaborn-talk')
plt.style.use('seaborn-white')

# %%
titanic_df = pd.read_csv('titanic_train.csv')
plt.figure(figsize=(10,7))
sns.countplot(x='Survived', data=titanic_df, hue='Pclass', palette='winter')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %% [markdown]
# ### Histogram

# %%
plt.figure(figsize=(8,6))
sns.histplot(titanic_df['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# ### Boxplot

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='Pclass',y='Age', data=titanic_df, palette='Accent', linewidth=3)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>
